# %%
fullname= input("enter a full name: ")
i=fullname.rfind(" ")
print(f"first name:{fullname[:i]}")
print(f"last name:{fullname[i+1:]}")
print(fullname.split())
# Out:
# first name:Naila
# last name:Dzulfa
# ['Naila', 'Dzulfa']

# %%
str="ijul"
print(len(str))
print(str.upper())
print(str.lower())
print(str.count('i'))
print(str.capitalize())
print(str.title())
print(" ijul".rstrip())
print(str.replace("i","o"))
# Out:
# 4
# IJUL
# ijul
# 1
# Ijul
# Ijul
#  ijul
# ojul

# %%
"ijul "+"anak "+"statbis "
# Out:
# 'ijul anak statbis '

# %%
print("python/java/c++".split("/"))
print("Python"[-1*len("Python")-1:3])
a=4
b=6
c="Municipality"
d="pal"
print(len(c))
print(c.upper())
print(c[a:b]+c[b+4:])
print(c.find("d"))
# Out:
# ['python', 'java', 'c++']
# Pyt
# 12
# MUNICIPALITY
# city
# -1

# %%
str1='James'
print(str1[0]+str1[2]+str1[4])
print(str1[::2])
# Out:
# New String: Jms
# Jms

# %%
c='Mahasiswa Teladan'.upper()
jmlA=c.count('A')
print(jmlA)
# Out:
# 5

# %%
print('M'+('m'*3)*2+".")
phoneNumber=2345678
print(f"Nomor Telfon saya adalah {phoneNumber}")
quote="Saya Mahasiswa Statistika Bisnis."
print(quote+":"+"ITS")
# Out:
# Mmmmmmm.
# Nomor Telfon saya adalah 2345678
# Saya Mahasiswa Statistika Bisnis.:ITS

# %%
#16
film="the great gatsby".title()[:10].rstrip()
print(film,len(film))

# %%
#17
str=input("Masukan String: ")
print(str[:-1], str[1:])
print(str[1:-1])
# Out:
# hal alo
# al

# %%
firstName="Thomas"
middleName="Alva"
lastName="Edison"
yearOfBirth="1847"
namaLengkap=firstName+" "+middleName+" "+lastName
print(f"Tahun kelahiran {namaLengkap} adalah {yearOfBirth}")
# Out:
# Tahun kelahiran Thomas Alva Edison adalah 1847

# %%
name=input("Please enter your full name: ")
num=len(name.replace(" ",""))
print(f"Hello {name}! Your name has {num} letters, excluding spaces.")
# Out:
# Hello Naila Dzulfa! Your name has 11 letters, excluding spaces.
