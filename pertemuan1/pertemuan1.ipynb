# %%
print('Hello World')
# Out:
# Hello World

# %%
x=7
y=8
print(x+y)
# Out:
# 15

# %%
print('y')
# Out:
# y

# %%
for i in range(8):
    print('ijul baik')
# Out:
# ijul baik
# ijul baik
# ijul baik
# ijul baik
# ijul baik
# ijul baik
# ijul baik
# ijul baik

# %%
print(3+1)
print(7+4)
# Out:
# 4
# 11

# %%
print(11-4%9)
print(5%5)
print(7//4)
print(10**2)
print(9%1)
print((7-4)/3)

print(5**10)
print(3+(4*5))
print((5+3)//10)
print(100%5)
print(7/4)
print((pow(2,3))+5)
# Out:
# 7
# 0
# 1
# 100
# 0
# 1.0
# 9765625
# 23
# 0
# 0
# 1.75
# 13

# %%
totalBerries=1000
totalCost=450
eachBerry=totalCost/totalBerries
print(eachBerry)
# Out:
# 0.45

# %%
points=70
points+=70*10
print(points)
# Out:
# 770

# %%
0.05=interest #pendeklarasian variabel terbalik seharusnya interest=0.05
balance=800
print(interest*balance)
# Out:
#   Cell In[21], line 1
#     0.05=interest
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a=2
b=3
a+b=c #pendeklarasian terbalik karena 
print(b)
# Out:
# 3
