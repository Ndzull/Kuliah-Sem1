# %%
def hitung_nilai_akhir(nama, nilai_uts, nilai_uas, nilai_tugas):
    nilai = (0.4 * nilai_uts) + (0.4 * nilai_uas) + (0.2 * nilai_tugas)
    output = print(f"Nilai {nama}: {nilai}") 
    return output 

orang=int(input("Mau berapa orang: "))
i=1
for i in range(orang):
    nama = input("Masukkan namamu: ")
    nilai_uts, nilai_uas, nilai_tugas = [float(x) for x in input("Masukkan nilai UTS, UAS, dan Tugas (dipisah dengan tanda spasi): \n").split()]
    hitung_nilai_akhir(nama, nilai_uts, nilai_uas, nilai_tugas)
    i+=1
# Out:
# Nilai Rini: 46.0
# Nilai Rina: 80.0

# %%
print("Hello WOrld")
# Out:
# Hello WOrld

# %%
def hitung_nilai_akhir(nama,nilai_uts,nilai_uas,nilai_tugas):
    nilai=(0.4*nilai_uts)+(0.4*nilai_uas)+(0.2*nilai_tugas)
    output=print(f"nilai {nama}: {nilai}")
    return output

hitung_nilai_akhir("Rina",90,90,40)
hitung_nilai_akhir("Rini",20,50,90)

# nama=input("Masukkan namamu: ")
# nilai_uts,nilai_uas,nilai_tugas=input("Masukan nilai UTS, UAS, dan Tugas (dipisah dengan tanda spasi):\n ").split()
# hitung_nilai_akhir(nama,nilai_uts,nilai_uas,nilai_tugas)
# Out:
# nilai Rina: 80.0
# nilai Rini: 46.0
