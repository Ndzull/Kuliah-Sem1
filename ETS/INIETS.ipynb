# %%
# Nama: Naila Dzulfa
# NRP: 2043251046
# Kelas: B Statistika Bisnis

# %%
#1
#a
bulan=input("Akan menginap pada bulan apa? ")
#b
lama=int(input("Berapa lama akan menginap(hari)? "))

studioMeiOkt=500000
apartmentMeiOkt=650000
studioJunSep=752000
apartmentJunSep=687000
studioJulAgu=760000
apartmentJulAgu=770000

#c
if(lama>3):
    if(bulan=="Mei" or bulan=="mei" or bulan=="Oktober" or bulan=="oktober"):
        studioMeiOkt*=0.85
        apartmentMeiOkt*=0.90
        print(f"Studio: {studioMeiOkt*lama}")
        print(f"Apartment: {apartmentMeiOkt*lama}")
    elif(bulan=="Juni" or bulan=="juni" or bulan=="September" or bulan=="september"):
        studioJunSep*=0.85
        apartmentJunSep*=0.90
        print(f"Studio: {studioJunSep*lama}")
        print(f"Apartment: {apartmentJunSep*lama}")
    elif(bulan=="Juli" or bulan=="juli" or bulan=="Agustus" or bulan=="agustus"):
        studioJulAgu*=0.85
        apartmentJulAgu*=0.90
        print(f"Studio: {studioJulAgu*lama}")
        print(f"Apartment: {apartmentJulAgu*lama}")
    else:
        print(f"ERROR! Bulan {bulan} tidak ditemukan")
    
else:
    if(bulan=="Mei" or bulan=="mei" or bulan=="Oktober" or bulan=="oktober"):
        print(f"Studio: {studioMeiOkt*lama}")
        print(f"Apartment: {apartmentMeiOkt*lama}")
    elif(bulan=="Juni" or bulan=="juni" or bulan=="September" or bulan=="september"):
        print(f"Studio: {studioJunSep*lama}")
        print(f"Apartment: {apartmentJunSep*lama}")
    elif(bulan=="Juli" or bulan=="juli" or bulan=="Agustus" or bulan=="agustus"):
        print(f"Studio: {studioJulAgu*lama}")
        print(f"Apartment: {apartmentJulAgu*lama}")
    else:
        print(f"ERROR! Bulan {bulan} tidak ditemukan")
# Out:
# Studio: 2256000
# Apartment: 2061000

# %%
#2
#a
data=[2,14,2,10,5,6,2]
n=0
data.remove(2)
data.remove(2)
data.remove(2)
print(data)
# Out:
# [14, 10, 5, 6]

# %%
#2
#a
data=[2,14,2,10,5,6,2]
for i in data:
    jumlah=data.count(i)
    if(jumlah>1):
        for j in range(jumlah!=0):
            data.remove(i)
data.remove(2) #udah nyerah bgt kenapa ga kehapus
print(data)
# Out:
# [14, 10, 5, 6]

# %%
#b
kalimat="menjadi mahasiswa yang dapat mengelola waktu dengan lebih baik"
kalimatPisah=kalimat.split()
print(kalimatPisah)
print(max(kalimatPisah, key=len))
# Out:
# ['menjadi', 'mahasiswa', 'yang', 'dapat', 'mengelola', 'waktu', 'dengan', 'lebih', 'baik']
# mahasiswa

# %%
#c
str1=["aku",13,"ok",55,"lama",10]
print(str1[1]+str1[3]+str1[5])
# Out:
# 78

# %%
#3
data_pengiriman=(("Laptop",2.5,"Surabaya",35000),("Printer",6.0,"Jakarta",55000),("Monitor",4.2,"bandung",45000),("Keyboard",1.2,"Surabaya",30000),("Mouse",0.5,"Jakarta",25000))

nama_barang=[data_pengiriman[0][0],data_pengiriman[1][0],data_pengiriman[2][0],data_pengiriman[3][0],data_pengiriman[4][0]]
berat_kg=[data_pengiriman[0][1],data_pengiriman[1][1],data_pengiriman[2][1],data_pengiriman[3][1],data_pengiriman[4][1]]
kota_tujuan=[data_pengiriman[0][2],data_pengiriman[1][2],data_pengiriman[2][2],data_pengiriman[3][2],data_pengiriman[4][2]]
biaya_pengiriman=[data_pengiriman[0][3],data_pengiriman[1][3],data_pengiriman[2][3],data_pengiriman[3][3],data_pengiriman[4][3]]

#a
print(f"Data pengiriman ke Surabaya: {data_pengiriman[0],data_pengiriman[3]}")
#b
print(f"Data total berat pengiriman ke Jakarta {berat_kg[1]+berat_kg[4]}kg")
#c
bandunglist=list(data_pengiriman[2])
bandunglist[3]=int(bandunglist[3]*1.1)
bandung=tuple(bandunglist)
print(f"Data pengiriman ke Bandung: {bandung}")
# Out:
# Data pengiriman ke Surabaya: (('Laptop', 2.5, 'Surabaya', 35000), ('Keyboard', 1.2, 'Surabaya', 30000))
# Data total berat pengiriman ke Jakarta 6.5kg
# Data pengiriman ke Bandung: ('Monitor', 4.2, 'bandung', 49500)

# %%
a=4
b=10
c=4
#a
root1=(-b+(b**2-4*a*c)**0.5)/(2*a)
print(root1)
#b
root2=(-b-(b**2-4*a*c)**0.5)/(2*a)
print(root2)
#c
diff=[2*a*1+b,2*a*2+b,2*a*3+b,2*a*4+b,2*a*5+b,2*a*6+b,2*a*7+b,2*a*8+b,2*a*9+b,2*a*10+b]
print(diff)
# Out:
# -0.5
# -2.0
# [18, 26, 34, 42, 50, 58, 66, 74, 82, 90]

# %%
#5
selusin=12
sekodi=20
#a
barang=input("Masukan nama barang: ")
jumlahAwal=input("Masukan jumlah satuan awal (pcs/lusin/kodi): ")
jumlahAkhir=input("Masukan jumlah satuan akhir (pcs/lusin/kodi): ")

#b & c
simpan=jumlahAwal.split(" ")
if(simpan[1]=="pcs" or simpan[1]=="PCS" or simpan[1]=="Pcs"):
    if(jumlahAkhir=="lusin" or jumlahAkhir=="Lusin" or jumlahAkhir=="LUSIN"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Total dalam lusin\t\t: {int(simpan[0])/selusin}")
    elif(jumlahAkhir=="kodi" or jumlahAkhir=="Kodi" or jumlahAkhir=="KODI"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Konversi ke kodi\t\t: {int(simpan[0])/sekodi}")
    else:
        print("Satuan akhir tidak ditemukan")
elif(simpan[1]=="lusin" or simpan[1]=="Lusin" or simpan[1]=="LUSIN"):   
    if(jumlahAkhir=="pcs" or jumlahAkhir=="PCS" or jumlahAkhir=="Pcs"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Total dalam pcs\t\t: {int(simpan[0])*selusin}")
    elif(jumlahAkhir=="kodi" or jumlahAkhir=="Kodi" or jumlahAkhir=="KODI"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Konversi ke kodi\t\t: {int(simpan[0])*selusin/sekodi}")
    else:
        print("Satuan akhir tidak ditemukan")
elif(simpan[1]=="kodi" or simpan[1]=="Kodi" or simpan[1]=="KODI"):
    if(jumlahAkhir=="pcs" or jumlahAkhir=="PCS" or jumlahAkhir=="Pcs"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Total dalam pcs\t: {int(simpan[0])*sekodi}")
    elif(jumlahAkhir=="lusin" or jumlahAkhir=="Lusin" or jumlahAkhir=="LUSIN"):
        print(f"Barang\t\t\t: {barang}")
        print(f"Jumlah awal\t\t: {simpan[0]} {simpan[1]}")
        print(f"Konversi ke lusin\t: {int(simpan[0])*sekodi/selusin}")
    else:
        print("Satuan akhir tidak ditemukan")
# Out:
# Barang		: pensil
# Jumlah awal	: 3 lusin
# Konversi ke kodi: 1.8
