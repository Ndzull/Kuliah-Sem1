# %%
gelas=int(input())
air=list(map(int,input().split()))
volume=sum(air)
max=1000
if(volume<max):
    print("Masih belum penuh ini mahh, tuang lagi dong")
elif(volume>max):
    print("Yahh tumpah, jadi mubazir deh")
elif(volume==max):
    print("Nahh pas nihh, tinggal minum deh")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gelas=int(input())
#       2 air=list(map(int,input().split()))
#       3 volume=sum(air)
#
# ValueError: invalid literal for int() with base 10: ''
