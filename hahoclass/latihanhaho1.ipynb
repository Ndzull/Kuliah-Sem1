# %%
nama=input("masukkan nama: ")

if(nama=="reval" or nama=="Reval"):
    print("wong gendeng")
elif(nama=="mas amar" or nama=="Mas Amar" or nama=="Mas amar" or nama=="mas Amar"):
    print("sedang tidur")
elif(nama=="hani" or nama=="Hani"):
    print("roben sedang mengetik...")
elif(nama=="ketzia" or nama=="Ketzia"):
    print("gwanteng")
else:
    print("siapa?")
# Out:
# gwanteng
