# %%
pendapatan=100.456
biaya=55.500
laba=pendapatan-biaya

# %%
pembelian=20
harga_penjualan=30
profit=harga_penjualan-pembelian
persenprofit=(100*(profit))//pembelian
print(f"profitnya: {profit}")
print(f"persen profitnya: {persenprofit}%")
# Out:
# profitnya: 10
# persen profitnya: 50%

# %%
saldo=100
saldo2=saldo+(saldo*0.05)+100
saldo3=saldo2+(saldo2*0.05)+100
saldoakhir=saldo3+saldo3*0.05
print(f"nilai keseimbangannya adalah:{(round(saldoakhir,2))}")
# Out:
# nilai keseimbangannya adalah:331.01

# %%
saldo=100
i=0
for i in range(2):
    saldo=saldo*0.05+saldo+100
    i+1

saldo=saldo+saldo*0.05
print(f"nilai keseimbangannya adalah:${(round(saldo,2))}")
# Out:
# nilai keseimbangannya adalah:$331.01

# %%
nama=input("masukkan nama: ")

if(nama=="reval"):
    print("wong gendeng")
elif(nama=="mas amar"):
    print("sedang tidur")
elif(nama=="hani"):
    print("roben sedang mengetik...")
elif(nama=="ketzia"):
    print("gwanteng")

# %%
t=6
r=4
pi=22/7
volumetabung=pi*(r**2)*t
luastabung=2*pi*r*(r+t)
print(f"Volume Tabung:{(round(volumetabung,3))}cm")
print(f"Luas Tabung:{(round(luastabung,3))}cm")
# Out:
# Volume Tabung:301.714cm
# Luas Tabung:251.429cm

# %%
str1="ijul"
print(str1[0],str1[2],str1[1:3]) #ju karena indeks 1 sampai 3-1
print(str1.find("i"))
#kalo ngga ada yang dicari outputnya -1
print(str1[-1])
print(str1[-1],str1[-4],str1[-3:-1])
# Out:
# i u ju
# 0
# l
# l i ju
