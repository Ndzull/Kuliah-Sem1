# %%
#halaman 32 no 1
print(11-4%9)
print(5%5)
print(7//4)
print(10**2)
print(9%1)
print((7-4)/3)
# Out:
# 7
# 0
# 1
# 100
# 0
# 1.0

# %%
#halaman 32 no 2
print(5**10)
print(3+(4*5))
print((5+3)//10)
print(100%5)
print(7/4)
print((2**3-1)+5)
# Out:
# 9765625
# 23
# 0
# 0
# 1.75
# 12

# %%
#halaman 32 no 3
var1=2
var2=3
var1=var2
print(var1)
# Out:
# 3

# %%
#halaman 32 no 3
var1=2
var2=3
var2=var1
print(var2)
# Out:
# 2

# %% [markdown]
# #perbedaannya adalah penyimpanan ke variabel yang mana

# %%
#halaman 32 no 4
a=3
print("{0:<20}{1:<5}{2:<5}".format(" ","a","b"))
print("{0:<20}{1:<5}{2:<5}".format("a=3",a," "))
b=a+5
print("{0:<20}{1:<5}{2:<5}".format("b=a+5",a,b))
print("{0:<20}{1:<5}{2:<5}".format("b=a+5",a,b))
print((a/b)+2)
print("{0:<20}{1:<5}{2:<5}".format("print((a/b)+2)",a,b)) #tidak mengubah karena tidak ada variabel yang dideklarasikan alias langsung dioutput
b=b%2+0.7
print("{0:<20}{1:<5}{2:<5}".format("b=b%2+0.7",a,b))
# Out:
#                     a    b
# a=3                 3
# b=a+5               3    8
# b=a+5               3    8
# 2.375
# print((a/b)+2)      3    8
# b=b%2+0.7           3    0.7

# %%
# Out:
#  	Bal	Inter	withDr
# inter=0.5	 	0.5
#  	 	0.5	25

# %%
#halaman 33 no 5
print(" \t\t\tbal\tInter\twithDr")
bal=100
print(f" \t\t\t{bal}\t \t ")
inter=0.5
print(f"inter=0.5\t\t{bal}\t{inter}\t ")
withDr=25
print(f"withDr=25\t\t{bal}\t{inter}\t{withDr}")
bal+=(inter*bal)
print(f"bal+=(inter*bal)\t{bal}\t{inter}\t{withDr}")
bal-=withDr
print(f"bal-=withDr\t\t{bal}\t{inter}\t{withDr}")
# Out:
#  			bal	Inter	withDr
#  			100
# inter=0.5		100	0.5
# withDr=25		100	0.5	25
# bal+=(inter*bal)	150.0	0.5	25
# bal-=withDr		125.0	0.5	25

# %%
#halaman 33 no 6
a=7
n=4
print(a*b**2)
#tidak ada kesalahan syntax apapun
# Out:
# 3.4299999999999997

# %%
#halaman 33 no 7
n=6
n** =4
print(n/5)
#pasti error karena tidak ada deklarasi pangkat (**) yang jelas
# Out:
#   Cell In[44], line 3
#     n** =4
#         ^
# SyntaxError: invalid syntax

# %%
#halaman 33 no 8
totalBerries=1000
totalCost=450
eachBerry=totalCost/totalBerries
print(eachBerry)
#tidak ada kesalahan syntax apapun
# Out:
# 0.45

# %%
#halaman 33 no 9
points=70
points+=70*10
print(points)
# Out:
# 770

# %%
#halaman 33 no 10
0.05=interest #pasti error karena syntax deklarasi variabel salah, seharusnya namaVar=isiVar
balance=800
print(interest*balance)
# Out:
#   Cell In[47], line 2
#     0.05=interest #pasti error karena syntax deklarasi variabel salah, seharusnya namaVar=isiVar
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#halaman 33 no 11
a=2
b=3
a+b=c #sama seperti nomor sebelumnya, formatnya sehausnya namaVar=isiVar
print(b)
# Out:
#   Cell In[48], line 4
#     a+b=c #sama seperti nomor sebelumnya, formatnya sehausnya namaVar=isiVar
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#halaman 33 no 12
print(int(7.75))
# Out:
# 7

# %%
#halaman 33 no 13
print(round(-7.5))

# %%
#halaman 33 no 14
b=8
print(int(b*0.5))

# %%
#halaman 33 no 15
print(int(9-2))

# %%
#halaman 33 no 16
print(round(71254.3))

# %%
#halaman 33 no 17
a=7
print(abs(a-5)) #tidak berguna karena integer disini bersifat positif

# %%
#halaman 33 no 18
pendapatan=100.456
biaya=55.500
laba=pendapatan-biaya
print(f"Keuntungannya adalah: Rp.{laba}")
# Out:
# Keuntungannya adalah: Rp.44.956

# %%
#halaman 33 no 19
hargaPembelian=20
hargaPenjualan=30
persentaseProfit=100*((hargaPenjualan-hargaPembelian)/hargaPembelian)
print(f"Persentase Profit: {persentaseProfit}%")
# Out:
# Persentase Profit: 50.0%

# %%
#halaman 33 no 20
saldo=100
saldo2=saldo+(saldo*0.05)+100
saldo3=saldo2+(saldo2*0.05)+100
saldoakhir=saldo3+saldo3*0.05
print(f"nilai keseimbangannya adalah:${(round(saldoakhir,2))}")
# Out:
# nilai keseimbangannya adalah:331.01

# %%
#halaman 33 no 20
saldo=100
i=0
for i in range(2):
    saldo=saldo*0.05+saldo+100
    i+1

saldo=saldo+saldo*0.05
print(f"nilai keseimbangannya adalah:${(round(saldo,2))}")
# Out:
# nilai keseimbangannya adalah:$331.01
