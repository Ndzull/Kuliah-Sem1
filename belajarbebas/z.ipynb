# %%
import a as f1
print("Coba input")
bil1=int(input("Masukan bilangan 1: "))
bil2=int(input("Masukan bilangan 2: "))
print(f"Hasil perkalian: {f1.perkalian(bil1,bil2)}")
# Out:
# Coba input
# Hasil perkalian: 12
