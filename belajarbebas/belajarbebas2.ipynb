# %%
x=1
if x>0:
    print("Nilai %x adalah lebih besar dari 0"%x)
# Out:
# Nilai 1 adalah lebih besar dari 0

# %%
nilai=3
if(nilai>7):
    print("Selamat anda lulus")
else:
    print("Maaf anda tidak lulus")
# Out:
# Maaf anda tidak lulus

# %%
number=5
if (number<0):
    print("negative")
else:
    if number==0:
        print("zero")
    else:
        print("positive")
# Out:
# positive

# %%
a=5
if(a>2) and ((a==3)or(a<7)):
    print("Halo")
# Out:
# Halo

# %%
n=eval(input("Enter a number: "))
if (n%2==0): #"n"%2=0:
    print("The number is an even number.")
else:
    print("The number is an odd number.")
# Out:
# The number is an even number.

# %%
departemen="Business Statistics"
if departemen=="Business Statistics" or "Computer Science": #major=="Business Statistics" Or "Computer Science":
    print("Yes")
# Out:
# Yes

# %%
number=6
if number>5 and number<9: #if number>5 and <9:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
if(a==7):
    print("tujuh")
else: #elif(a!=7):
    print("sebelas")
# Out:
# sebelas

# %%
umur=int(input("Masukan umur: "))
if umur>25:
    print("Orang itu dewasa")
elif umur>=17 and umur<=25:
    print("Orang itu remaja")
else:
    print("Orang itu belum remaja apalagi dewasa")
# Out:
# Orang itu remaja
