# %%
saham=[["Senin", 2056.45]["Selasa",2044.38]["Rabu",2105.21]["Kamis",3113.03]["Jum'at",2098.72]]
print(min(saham[0][1],saham[1][1],saham[2][1],saham[3][1],saham[4][1]))
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\naiid\AppData\Local\Temp\ipykernel_1044\1230872645.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   saham=[["Senin", 2056.45]["Selasa",2044.38]["Rabu",2105.21]["Kamis",3113.03]["Jum'at",2098.72]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 saham=[["Senin", 2056.45]["Selasa",2044.38]["Rabu",2105.21]["Kamis",3113.03]["Jum'at",2098.72]]
#       2 print(min(saham[0][1],saham[1][1],saham[2][1],saham[3][1],saham[4][1]))
#
# TypeError: list indices must be integers or slices, not tuple

# %%
data=[]
waktu=int(input("Waktu ke-1"))
data.append(waktu)
waktu=int(input("Waktu ke-2"))
data.append(waktu)
waktu=int(input("Waktu ke-3"))
data.append(waktu)
waktu=int(input("Waktu ke-4"))
data.append(waktu)
waktu=int(input("Waktu ke-5"))
data.append(waktu)
waktu=int(input("Waktu ke-6"))
data.append(waktu)

mean=sum(data)/len(data)
print(f"{mean:.2f}")
std=(((data[0]-mean)**2)+((data[1]-mean)**2)+((data[2]-mean)**2)+((data[3]-mean)**2)+((data[4]-mean)**2)+((data[5]-mean)**2))/len(data)
print(f"{std:.2f}")

print(max(data))
print(min(data))

data.sort()

q1=int(1*(len(data)+1)/4)
print(q1)
print(data[q1])

q2=int(2*(len(data)+1)/4)
print(q2)
print(data[q2])

q3=int(3*(len(data)+1)/4)
print(q3)
print(data[q3],chr(176))
# Out:
# 3.50
# 2.92
# 6
# 1
# 1
# 2
# 3
# 4
# 5
# 6 °

# %%
customers=["Mrs. Ana Sugandi", "Mr. Nur Ridho","Mr. Dedy Setiawan","Mx. Hillary"]
nama=[]
hapus=customers[0].split(". ")
nama.append(hapus[1])
hapus=customers[1].split(". ")
nama.append(hapus[1])
hapus=customers[2].split(". ")
nama.append(hapus[1])
hapus=customers[3].split(". ")
nama.append(hapus[1])
print(nama)
# Out:
# ['Ana Sugandi', 'Nur Ridho', 'Dedy Setiawan', 'Hillary']
