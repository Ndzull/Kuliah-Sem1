# %%
print("Hello WOrld")
# Out:
# Hello WOrld

# %%
i=1
while(i<=5):
    print("Statistika Bisnis")
    i+=1
print("Loop selesai")
# Out:
# Statistika Bisnis
# Statistika Bisnis
# Statistika Bisnis
# Statistika Bisnis
# Statistika Bisnis
# Loop selesai

# %%
list1=[7,7,10,8]
total=0
while list1:
    total+=list1[0]
    list1=list1[1:]
print(total)
# Out:
# 32
# []

# %%
berhitung=5
while(berhitung>=2):
    print(berhitung)
    berhitung-=1
# Out:
# 5
# 4
# 3
# 2

# %%
x="Statistika Bisnis"
while x:
    print(x)
    x=x[1:]
# Out:
# Statistika Bisnis
# tatistika Bisnis
# atistika Bisnis
# tistika Bisnis
# istika Bisnis
# stika Bisnis
# tika Bisnis
# ika Bisnis
# ka Bisnis
# a Bisnis
#  Bisnis
# Bisnis
# isnis
# snis
# nis
# is
# s

# %%
x="Statistika Bisnis"
while x:
    print(x,"")
    x=x[1:]
# Out:
# Statistika Bisnis
# tatistika Bisnis
# atistika Bisnis
# tistika Bisnis
# istika Bisnis
# stika Bisnis
# tika Bisnis
# ika Bisnis
# ka Bisnis
# a Bisnis
#  Bisnis
# Bisnis
# isnis
# snis
# nis
# is
# s

# %%
L=[2,4,6,8]
total=0
for l in L:
    total+=l 
print(total)
# Out:
# 20
# [2, 4, 6, 8]

# %%
q=1
while(q!=0):
    q=q-1
    print(q)
# Out:
# 0

# %%
list1=["H","e","l","l","o"]
i=len(list1)
while(i>1):
    i-=1
    print(list1)
# Out:
# ['H', 'e', 'l', 'l', 'o']
# ['H', 'e', 'l', 'l', 'o']
# ['H', 'e', 'l', 'l', 'o']
# ['H', 'e', 'l', 'l', 'o']
