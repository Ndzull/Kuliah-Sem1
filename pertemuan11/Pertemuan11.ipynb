# %%
print("Hello World")
# Out:
# Hello World

# %%
a=int(input("coba masukin angka: "))
if(a==1):
    print("Angkanya satu ya")
else:
    print("pasti bukan 1")
# Out:
# Angkanya satu ya

# %%
a=12
b=10
if(a>b):
    print("a lebih besar dari b")
else:
    print("a lebih kecil dari b")
# Out:
# a lebih besar dari b
